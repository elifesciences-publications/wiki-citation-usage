# %% [markdown]
# ## Infobox and Section Events

# %%
# basic defaults, including study dates, common SQL exclusions and parquet files for anonymized data
# %run -i 'data-defaults.py'

# %%
# Infobox clicks that occurred under a section heading (e.g. External links)
# no limits
infobox_section_events_query = """
SELECT section_id, action, count(*) count
FROM
    citationusage
WHERE
    wiki = 'enwiki'
    AND in_infobox = TRUE
    {}
    AND useragent_is_bot = FALSE
GROUP BY section_id, action
ORDER BY count desc
"""

infobox_section_events = spark.sql(infobox_section_events_query.format(event_exclusion_sql))
infobox_section_events_rdd = infobox_section_events.rdd
infobox_section_events_df = sqlContext.createDataFrame(infobox_section_events_rdd)
infobox_section_events_df.toPandas()
# Out:
#                                               section_id    action     count
# 0                                                   None  extClick  14979994
# 1                                                   None   fnClick   1849201
# 2                                                   None   fnHover   1107570
# 3                                              Reception   fnClick     28389
# 4                                              Reception   fnHover     13881
# 5                                         External_links  extClick      7268
# 6                                               Timeline  extClick      4907
# 7                                               Rankings   fnClick      4270
# 8                                               Rankings   fnHover      3925
# 9                                     In_popular_culture  extClick      3107
# 10                                         Bonnie_Parker  extClick      2648
# 11                                            Soundtrack  extClick      2208
# 12                                        Elevator_video  extClick      2046
# 13                                                Career  extClick      2020
# 14                                               History  extClick      1918
# 15                                         Assassination  extClick      1774
# 16                                   Professional_career  extClick      1671
# 17                                 Gesundheit!_Institute  extClick      1492
# 18                                   Body_camera_footage  extClick      1425
# 19                                                Events  extClick      1392
# 20                                          Clyde_Barrow  extClick      1290
# 21                                              See_also  extClick      1128
# 22                                    Critical_reception   fnClick      1125
# 23               1931–1933:_Travels_in_the_United_States  extClick      1029
# 24                                        Holliday_video  extClick       964
# 25                                         Pronunciation  extClick       946
# 26     Return_to_Mexico_City_and_international_recogn...  extClick       942
# 27                             Disappearance_and_charges  extClick       910
# 28                               Rankings_and_reputation   fnHover       880
# 29                                            Government   fnHover       854
# ...                                                  ...       ...       ...
# 11127                                   Listed_buildings  extClick         1
# 11128                                   Bitbucket_Server   fnHover         1
# 11129                         Transformers_film_universe   fnHover         1
# 11130                                   En_Vogue_version   fnClick         1
# 11131                                     Sturmgewehr_58   fnClick         1
# 11132                                  Mistletoe_and_Rum  extClick         1
# 11133                                   Medium_champagne   fnClick         1
# 11134                                    East_Coast_Tour   fnClick         1
# 11135                       Ninth_generation_(2000–2006)   fnHover         1
# 11136                     Week_12:_vs._Green_Bay_Packers  extClick         1
# 11137                          Murder_of_Reeva_Steenkamp   fnClick         1
# 11138                                               Dome   fnClick         1
# 11139                    Research_Centres_and_Institutes   fnHover         1
# 11140                                          Bud_green  extClick         1
# 11141                       First_generation_(1952–1955)   fnHover         1
# 11142  Pepperspraying_at_Occupy_Wall_Street_-_Septemb...  extClick         1
# 11143                                   Adventure_sports  extClick         1
# 11144                                           Old_rose  extClick         1
# 11145                       First_generation_(1996–2008)   fnHover         1
# 11146                         BMT_Canarsie_Line_platform   fnHover         1
# 11147                                Pretoria_Harlequins  extClick         1
# 11148          Town_of_Bermuda_Hundred_Historic_District  extClick         1
# 11149            Assault_on_the_House_of_Representatives  extClick         1
# 11150                           Martin_Orthopedic_School  extClick         1
# 11151                     Discovery_Series_I_(1989–1998)   fnClick         1
# 11152                                           Football   fnHover         1
# 11153                        National_Historic_Landmarks  extClick         1
# 11154                 Second_generation_(G50;_1997–2016)   fnClick         1
# 11155                                         Mobile_app   fnHover         1
# 11156                                   Lake_description  extClick         1
#
# [11157 rows x 3 columns]

# %%
# Total count of events (by all event types) for each top-level (H2) section ID for WP:M pages only
# where the event also occurred in an InfoBox
pm_section_events_query = """
SELECT wpm_sections.section_h2, action, count(*) count
FROM 
    citationusage
    LEFT JOIN ryanmax.wpm_sections 
        ON 
        wpm_sections.page_id = citationusage.page_id 
        AND wpm_sections.section_id = citationusage.section_id
WHERE
    wiki = 'enwiki'
    AND in_infobox = TRUE
    AND citationusage.page_id IN (
                            SELECT DISTINCT page_id 
                            FROM ryanmax.projmed_with_extlinks 
                            WHERE to_date(dt) >= '{}' AND to_date(dt) <= '{}'
                        )
    {}
    AND to_date(citationusage.event_time) >= '{}'
    AND to_date(citationusage.event_time) <= '{}'
    AND useragent_is_bot = FALSE
    AND session_id in (
        SELECT session_id
        FROM citationusagepageload
        WHERE wiki = 'enwiki'
        {}
        AND to_date(event_time) >= '{}'
        AND to_date(event_time) <= '{}'
        AND useragent_is_bot = FALSE
        )
GROUP BY wpm_sections.section_h2, action
ORDER BY count desc
"""

pm_section_events = spark.sql(
    pm_section_events_query.format(
        start_date_string, end_date_string,
        event_exclusion_sql, start_date_string, end_date_string,
        pageload_exclusion_sql, start_date_string, end_date_string,
    ))
pm_section_events_rdd = pm_section_events.rdd
pm_section_events_df = sqlContext.createDataFrame(pm_section_events_rdd)
pm_section_events_pandas = pm_section_events_df.toPandas()

# %%
section_pda = pm_section_events_pandas.copy()
# replace 'NaN' section_h2 with 'missing'
section_pda.section_h2.fillna(value='-- Infobox event outside of a section --', inplace=True)
# limit to counts of 1K or more
section_pda['count'] = section_pda['count'].astype(int)
df_filtered = section_pda.query('count>=5').copy()
# set precision before pivot
df_filtered['count'] = df_filtered['count'].map(lambda x: '{0:.0f}'.format(x))
display(Markdown("### Count of Infobox events (by all event types) occurring under each top-level (H2) section ID"))
display(Markdown("#### Limits: WP:M pages and >= 5 events"))
df_filtered.pivot(index='section_h2', columns='action', values='count')
# Out:
# ### Count of Infobox events (by all event types) occurring under each top-level (H2) section ID
# #### Limits: WP:M pages and >= 5 events
# action                                   extClick fnClick fnHover
# section_h2
# -- Infobox event outside of a section --    34803   18400    6641
# Academics                                    None       6       6
# Battle_with_schools                          None       7       5
# Books                                           9    None    None
# Causes                                       None    None       6
# Common_families_of_interleukins                10    None    None
# Diagnosis                                       5    None    None
# External_links                               1095    None    None
# Family_and_birth                               19    None    None
# Ganfyd                                          5    None    None
# History                                        26    None    None
# History,_society,_and_culture                  15    None    None
# Institute_for_Functional_Medicine              31    None    None
# Legacy                                          8    None    None
# Levels                                          9    None    None
# Mechanism_of_action                            13    None    None
# Mental_changes_and_brain_damage                20    None    None
# Occurrence                                     58    None    None
# Origin_of_term                                 12    None    None
# Overview                                       15    None    None
# Pathophysiology                                 8    None    None
# Rescue                                         13    None    None
# School_of_Medicine                           None    None       7
# Selected_publications                          16    None    None
# Signs_and_symptoms                             41    None    None
# Versions                                        5    None    None
# ZDoggMD                                        13    None    None
